# %%
import vk
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from numpy import *
from pandas import *
from seaborn import *
from collections import Counter
from matplotlib import pylab
from pylab import *
from ChernoffFace import *

# %%
access_t='vk1.a.I_2IStvCV2RmOjhYZPGpG5i2J4w29fqywAtnUg49tsTt830Ya-u6DI1m6yF1eW21UsNqdjaBf1WgSzrrRjJUw6SFK7cDVW53E7LqaoUlFyDS6FY6yTydk_hLDI2PLYUjILu2YvfMobFxNt8jsGCfLuuPBIMNtqPAKastcy_anZV4dIf9yBKc0czUePaLYESOicYCfk2a40bQAzQ9nReV0g'
vk_api=vk.API(access_token=access_t)

# %%
userLeaderList = [67323233, 417439506, 72525096, 37310136, 82928435, 337140314, 234030319, 273203481, 414820807, 466392242]
userFields = ["bdate","city","country","sex", "followers_count", "has_photo", "last_seen", "online", "relation"]
users = vk_api.users.get(user_ids=userLeaderList,fields=userFields, v=5.131)
users[0]
# Out:
# {'id': 67323233,
#  'bdate': '8.5.1975',
#  'city': {'id': 12269, 'title': 'Вельск'},
#  'country': {'id': 1, 'title': 'Россия'},
#  'has_photo': 1,
#  'last_seen': {'platform': 7, 'time': 1672149645},
#  'followers_count': 439,
#  'relation': 4,
#  'relation_partner': {'id': 55923235,
#   'first_name': 'Андрей',
#   'last_name': 'Белых'},
#  'sex': 1,
#  'online': 0,
#  'first_name': 'Валентина',
#  'last_name': 'Иванова',
#  'can_access_closed': True,
#  'is_closed': False}

# %%
friendlistsList = []
for i in users:
    listToChange = ['city', 'country']
    for ii in listToChange:
        try:
            i[f'{ii}'] = i[f'{ii}']['title']
        except:
            i[f'{ii}'] = "NaN"

    try:
        i['last_seen'] = i['last_seen']['time']
    except:
        i[f'last_seen'] = "0"
    
    try:
        i['relation_partner'] = i['relation_partner']['id']
    except:
        i[f'relation_partner'] = "NaN"
    
    
    try:
        friendlistsList.append(vk_api.friends.get(user_id=i['id'], v=5.131)['items'])
    except:
        friendlistsList.append("NaN")

# %%
df_raw = DataFrame(data=users)

# %%
countFriendsList = []
for i in friendlistsList:
    if i == "NaN":
        countFriendsList.append(0)
    else:
        countFriendsList.append(len(i))
countFriendsList
# Out:
# [5000, 5000, 5000, 1076, 5000, 837, 5000, 0, 0, 0]

# %%
df = df_raw.assign(FriendsCount=countFriendsList)
df
# Out:
#           id      bdate    city country  has_photo   last_seen  \
# 0   67323233   8.5.1975  Вельск  Россия          1  1672149645
# 1  417439506        NaN  Вельск  Россия          1  1672067811
# 2   72525096  14.4.1978  Вельск  Россия          1  1672150239
# 3   37310136   5.1.1989  Вельск  Россия          1  1672149592
# 4   82928435        1.8  Вельск  Россия          1  1672150270
# 5  337140314        NaN  Вельск  Россия          1  1672147719
# 6  234030319       8.12     NaN  Россия          1  1672130886
# 7  273203481        NaN     NaN  Россия          1  1672147535
# 8  414820807        NaN  Вельск  Россия          1  1672148966
# 9  466392242        NaN     NaN     NaN          1  1672150295
#
#    followers_count  relation relation_partner  sex  online  \
# 0            439.0       4.0         55923235    1       0
# 1              2.0       0.0              NaN    2       0
# 2            352.0       NaN              NaN    1       1
# 3            701.0       4.0              NaN    1       0
# 4            936.0       NaN              NaN    1       1
# 5            205.0       0.0              NaN    1       0
# 6            298.0       NaN              NaN    1       0
# 7              NaN       NaN              NaN    1       0
# 8              2.0       0.0              NaN    1       0
# 9              NaN       NaN              NaN    1       1
#
#                first_name   last_name  can_access_closed  is_closed  \
# 0               Валентина     Иванова               True      False
# 1  Вельский-Краеведческий       Музей               True      False
# 2                  Марина     Петрова               True      False
# 3                 Евгения    Арбузова               True      False
# 4                   Ирина     Власова               True      False
# 5                 Наталья  Тюрюханова               True      False
# 6                    Анна  Мастерская               True      False
# 7                Светлана   Овсянкина              False       True
# 8                 Наталия    Шалагина               True      False
# 9                Лизавета     Красота              False       True
#
#    online_mobile  online_app  FriendsCount
# 0            NaN         NaN          5000
# 1            NaN         NaN          5000
# 2            NaN         NaN          5000
# 3            NaN         NaN          1076
# 4            1.0   2274003.0          5000
# 5            NaN         NaN           837
# 6            NaN         NaN          5000
# 7            NaN         NaN             0
# 8            NaN         NaN             0
# 9            1.0   3140623.0             0

# %%
df2 = df[['id', 'first_name', 'bdate', 'city','last_seen','sex','online','is_closed','can_access_closed','FriendsCount']]
to_numeric(df2['FriendsCount'])
to_numeric(df2['sex'])
to_numeric(df2['online'])
to_numeric(df2['last_seen'])

fig = chernoff_face(data=df2, 
                    titles=df["first_name"].to_list(), 
                    n_columns=3,
                    long_face=False,
                    figsize=(10, 10),
                    color_mapper=matplotlib.cm.Pastel1,
                    dpi=100)

# Display
fig.tight_layout()
plt.show()

# %%
#Круговая
#Данные
data = Counter(df['city'])
labels = data.keys()
sizes = data.values()

plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=210)
plt.title('Город проживания')
plt.show()

histplot(df, 
        x="country", 
        multiple="stack", 
        hue="city", 
        discrete=True,
        linewidth=0)
plt.title('Страна проживания')
plt.show()

# %%
df.to_csv('data.csv')
